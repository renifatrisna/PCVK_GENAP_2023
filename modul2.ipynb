# %% [markdown]
# <a href="https://colab.research.google.com/github/renifatrisna/PCVK_GENAP_2023/blob/main/modul2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Praktikum**

# %% [markdown]
# **1.**

# %%
from google.colab import drive

# Accessing my Google Drive
drive.mount('/content/drive')

import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

img = cv.imread('/content/drive/MyDrive/koceng.jpg')
plt.imshow(img)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# 2.

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %% [markdown]
# **3.**

# %%
img_gray = cv.imread('/content/drive/MyDrive/koceng.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)
fig = plt.figure(figsize=(10,10))   
ax = fig.add_subplot(111)
ax.imshow(img5)

# %% [markdown]
# **4.**

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))    #Nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yg mewakili R, G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# # **Tugas**

# %% [markdown]
# # **1.**

# %%
# Green-Blue (Remove Red)
import cv2
import numpy as np

img_tg1a = cv2.imread('/content/drive/MyDrive/koceng.jpg', cv2.COLOR_BGR2RGB)
img_tg1a[:,:,2] = np.zeros([img_tg1a.shape[0], img_tg1a.shape[1]])
plt.imshow(img_tg1a)

# %%
# Red-Green (Remove Blue)
img_tg1b = cv2.imread('/content/drive/MyDrive/koceng.jpg', cv2.COLOR_BGR2RGB)
img_tg1b[:,:,0] = np.zeros([img_tg1b.shape[0], img_tg1b.shape[1]])
plt.imshow(img_tg1b)

# %% [markdown]
# # **2.**

# %%
img_tg2 = cv.imread('/content/drive/MyDrive/koceng.jpg')
plt.imshow(img_tg2[10:100,10:100])

# %% [markdown]
# # **3.**

# %%
img_tg3 = cv.imread('/content/drive/MyDrive/koceng.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_tg3[5:30], cmap='Greens')

# %% [markdown]
# # **4.**

# %%
img_tg4 = cv.imread('/content/drive/MyDrive/koceng.jpg',cv.COLOR_BGR2RGB)

fig = plt.figure(figsize=(10,10))
cv.rectangle(img_tg4,pt1=(200,0),pt2=(510,300),color=(50,150,255),thickness=10)
cv.rectangle(img_tg4,pt1=(1000,100),pt2=(1200,300),color=(255,255,255),thickness=10)
cv.rectangle(img_tg4,pt1=(100,600),pt2=(325,900),color=(0,255,0),thickness=10)
cv.rectangle(img_tg4,pt1=(100,120),pt2=(175,300),color=(250,0,0),thickness=10)
cv.rectangle(img_tg4,pt1=(800,700),pt2=(1200,800),color=(255,0,250),thickness=10)
plt.imshow(img_tg4)

# %% [markdown]
# # **5.**

# %%
img_tg5 = cv.flip(cv.cvtColor(img_tg4,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img_tg5)

# %% [markdown]
# # **6.**

# %%
img_tg6 = cv.imread('/content/drive/MyDrive/koceng.jpg')

cv.rectangle(img_tg6,pt1=(900,600),pt2=(500,200),color=(0,255,0),thickness=5)
cv.circle(img_tg6,center=(700,450),radius=180,color=(255,0,0),thickness=5)
plt.imshow(img_tg6)

# %% [markdown]
# # **7.**

# %%
img_tg7 = cv.imread('/content/drive/MyDrive/koceng.jpg')
img_rgb7 = cv.cvtColor(img_tg7, cv.COLOR_BGR2RGB)

cv.rectangle(img_rgb7,pt1=(0,900),pt2=(200,600),color=(0,255,0),thickness=10)
plt.imshow(img_rgb7)
